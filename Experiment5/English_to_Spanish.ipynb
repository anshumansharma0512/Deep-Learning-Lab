# %% [markdown]
# <a href="https://colab.research.google.com/github/anshumansharma0512/Deep-Learning-Lab/blob/main/English_to_Spanish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sequence-to-Sequence Learning with LSTM

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
from torch.nn.utils.rnn import pad_sequence
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction

# Check If CUDA is Available, Else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

modes = ["without_attention", "bahdanau", "luong"]

# Load Dataset
def load_data(path, limit = 10000):
    with open(path, "r", encoding = 'utf-8') as f:
        lines = [line.strip().split('\t') for line in f if '\t' in line]
    random.shuffle(lines)

    return lines[:limit]

# Build Vocabulary
def build_vocab(sentences):
    vocab = {'<pad>': 0, '<sos>': 1, '<eos>': 2, '<unk>': 3}
    counter = Counter(word for s in sentences for word in s.lower().split())
    for word in counter:
        vocab[word] = len(vocab)

    return vocab

# Tokenize Sentence
def tokenize(sentence, vocab):
    return [vocab.get(w, vocab['<unk>']) for w in sentence.lower().split()]

# Prepare Dataset
def prepare_dataset(pairs, src_vocab, tgt_vocab):
    X, Y = [], []
    for src, tgt in pairs:
        x = tokenize(src, src_vocab)
        y = [tgt_vocab['<sos>']] + tokenize(tgt, tgt_vocab) + [tgt_vocab['<eos>']]
        X.append(torch.tensor(x, dtype = torch.long))
        Y.append(torch.tensor(y, dtype = torch.long))

    return X, Y

# Pad Batch
def collate_fn(batch_x, batch_y):
    src = pad_sequence(batch_x, batch_first = True, padding_value = src_vocab['<pad>'])
    tgt = pad_sequence(batch_y, batch_first = True, padding_value = tgt_vocab['<pad>'])
    return src.to(device), tgt.to(device)

# Encoder
class Encoder(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, batch_first = True)

    def forward(self, x):
        x = self.embedding(x)
        outputs, (h, c) = self.lstm(x)

        return outputs, (h, c)

# Bahdanau Attention
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attn = nn.Linear(hidden_size * 2, hidden_size)
        self.v = nn.Parameter(torch.rand(hidden_size))

    def forward(self, hidden, encoder_outputs):
        hidden = hidden[-1].unsqueeze(1).repeat(1, encoder_outputs.size(1), 1)
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2)))
        score = torch.sum(self.v * energy, dim = 2)

        return torch.softmax(score, dim = 1)

# Luong Attention
class LuongAttention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attn = nn.Linear(hidden_size, hidden_size)

    def forward(self, hidden, encoder_outputs):
        hidden = hidden[-1].unsqueeze(2)
        energy = self.attn(encoder_outputs)
        score = torch.bmm(energy, hidden).squeeze(2)

        return torch.softmax(score, dim = 1)

# Decoder
class Decoder(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, mode):
        super().__init__()
        self.mode = mode
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.attn = BahdanauAttention(hidden_size) if mode == "bahdanau" else \
                    LuongAttention(hidden_size) if mode == "luong" else None
        self.lstm = nn.LSTM(embed_size + hidden_size if self.attn else embed_size, hidden_size, batch_first = True)
        self.fc = nn.Linear(hidden_size * 2 if self.attn else hidden_size, vocab_size)

    def forward(self, x, hidden, cell, encoder_outputs = None):
        x = self.embedding(x.unsqueeze(1))
        attn_weights = None
        if self.attn:
            attn_weights = self.attn(hidden, encoder_outputs)
            context = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)
            x = torch.cat((x, context), dim = 2)
        output, (hidden, cell) = self.lstm(x, (hidden, cell))
        if self.attn:
            output = torch.cat((output.squeeze(1), context.squeeze(1)), dim = 1)
        else:
            output = output.squeeze(1)

        return self.fc(output), hidden, cell, attn_weights

# Seq2Seq Model
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, src, tgt, teacher_forcing = 0.5):
        batch_size, tgt_len = tgt.shape
        vocab_size = self.decoder.fc.out_features
        outputs = torch.zeros(batch_size, tgt_len, vocab_size).to(device)
        enc_outputs, (h, c) = self.encoder(src)
        x = tgt[:, 0]
        for t in range(1, tgt_len):
            out, h, c, _ = self.decoder(x, h, c, enc_outputs if self.decoder.attn else None)
            outputs[:, t] = out
            x = tgt[:, t] if random.random() < teacher_forcing else out.argmax(1)

        return outputs

# Training the Model
# Training the Model
def train(model, xdata, ydata, val_data = None, epochs = 5):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
    criterion = nn.CrossEntropyLoss(ignore_index=tgt_vocab['<pad>'])
    for epoch in range(epochs):
        total_loss = 0
        for i in range(0, len(xdata), 64):
            src, tgt = collate_fn(xdata[i:i+64], ydata[i:i+64])
            output = model(src, tgt)
            loss = criterion(output[:, 1:].reshape(-1, output.shape[-1]), tgt[:, 1:].reshape(-1))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        if val_data:
            model.eval()
            val_x, val_y = val_data
            with torch.no_grad():
                src, tgt = collate_fn(val_x, val_y)
                output = model(src, tgt)
                val_loss = criterion(output[:, 1:].reshape(-1, output.shape[-1]), tgt[:, 1:].reshape(-1))
            print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}, Validation Loss: {val_loss.item():.4f}")
            model.train()
        else:
            print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")

# Translate
def translate(model, sentence):
    model.eval()
    tokens = tokenize(sentence, src_vocab)
    src = torch.tensor(tokens).unsqueeze(0).to(device)
    enc_outputs, (h, c) = model.encoder(src)
    x = torch.tensor([tgt_vocab['<sos>']]).to(device)
    result = []
    for _ in range(20):
        out, h, c, _ = model.decoder(x, h, c, enc_outputs if model.decoder.attn else None)
        x = out.argmax(1)
        word = tgt_ivocab[x.item()]
        if word == "<eos>":
            break
        result.append(word)

    return ' '.join(result)

# BLEU Evaluation
def evaluate_bleu(model):
    refs, preds = [], []
    for x, y in zip(X_test[:100], Y_test[:100]):
        src_sent = ' '.join([src_ivocab[t.item()] for t in x])
        tgt_sent = [tgt_ivocab[t.item()] for t in y[1:-1]]
        pred = translate(model, src_sent).split()
        refs.append([tgt_sent])
        preds.append(pred)

    smoothing = SmoothingFunction().method1
    return corpus_bleu(refs, preds, smoothing_function = smoothing)

# Attention Visualization
def visualize_attention(model, sentence):
    if MODE == "without_attention":
        print("No Attention to Visualize.")
        return
    model.eval()
    tokens = tokenize(sentence, src_vocab)
    src = torch.tensor(tokens).unsqueeze(0).to(device)
    enc_outputs, (h, c) = model.encoder(src)
    x = torch.tensor([tgt_vocab['<sos>']]).to(device)
    result = []
    attentions = []
    for _ in range(20):
        out, h, c, attn = model.decoder(x, h, c, enc_outputs)
        x = out.argmax(1)
        word = tgt_ivocab[x.item()]
        if word == "<eos>":
            break
        result.append(word)
        attentions.append(attn.squeeze(0).cpu().detach().numpy())

    src_words = [src_ivocab[i] for i in tokens]
    fig = plt.figure(figsize = (10, 6))
    ax = fig.add_subplot(111)
    cax = ax.matshow(np.stack(attentions), cmap = "viridis")
    ax.set_xticks(range(len(src_words)))
    ax.set_yticks(range(len(result)))
    ax.set_xticklabels(src_words, rotation = 45)
    ax.set_yticklabels(result)
    ax.set_xlabel("Input Words")
    ax.set_ylabel("Output Words")
    plt.colorbar(cax)
    plt.title(f"Attention ({MODE})")
    plt.show()

# Load and Prepare Data
pairs = load_data("spa.txt")

src_text = [pair[0] for pair in pairs]
tgt_text = [pair[1] for pair in pairs]
src_vocab = build_vocab(src_text)
tgt_vocab = build_vocab(tgt_text)
src_ivocab = {i: w for w, i in src_vocab.items()}
tgt_ivocab = {i: w for w, i in tgt_vocab.items()}

X, Y = prepare_dataset(pairs, src_vocab, tgt_vocab)

# 10% Split for Test
X_temp, X_test, Y_temp, Y_test = train_test_split(X, Y, test_size = 0.1)

# 10% Split for Validation
X_train, X_val, Y_train, Y_val = train_test_split(X_temp, Y_temp, test_size = 0.1111)

# Run all Modes
for MODE in modes:
    print(f"\nRunning Mode: {MODE.upper()}")

    encoder = Encoder(len(src_vocab), 256, 512).to(device)
    decoder = Decoder(len(tgt_vocab), 256, 512, MODE).to(device)
    model = Seq2Seq(encoder, decoder).to(device)

    train(model, X_train, Y_train, val_data = (X_val, Y_val), epochs = 200)

    print("Translate:", translate(model, "I am happy."))
    print("BLEU Score:", evaluate_bleu(model))

    if MODE != "without_attention":
        visualize_attention(model, "I am happy.")
    else:
        print("No Attention Visualization (without_attention Mode).")
# Out:
# Running Mode: WITHOUT_ATTENTION
# Epoch 1, Loss: 818.0990, Validation Loss: 6.2825
# Epoch 2, Loss: 735.0804, Validation Loss: 6.1867
# Epoch 3, Loss: 698.4260, Validation Loss: 5.9656
# Epoch 4, Loss: 659.6442, Validation Loss: 5.8619
# Epoch 5, Loss: 621.4458, Validation Loss: 5.8833
# Epoch 6, Loss: 580.6800, Validation Loss: 5.7171
# Epoch 7, Loss: 538.7807, Validation Loss: 5.7182
# Epoch 8, Loss: 507.5639, Validation Loss: 5.6349
# Epoch 9, Loss: 466.0632, Validation Loss: 5.5454
# Epoch 10, Loss: 429.4212, Validation Loss: 5.8096
# Epoch 11, Loss: 395.0772, Validation Loss: 5.9030
# Epoch 12, Loss: 368.0933, Validation Loss: 5.7392
# Epoch 13, Loss: 320.5199, Validation Loss: 5.7354
# Epoch 14, Loss: 286.0455, Validation Loss: 6.1525
# Epoch 15, Loss: 253.7066, Validation Loss: 6.1648
# Epoch 16, Loss: 222.5979, Validation Loss: 5.7925
# Epoch 17, Loss: 197.4445, Validation Loss: 5.8506
# Epoch 18, Loss: 169.7503, Validation Loss: 6.0818
# Epoch 19, Loss: 151.3947, Validation Loss: 5.8560
# Epoch 20, Loss: 124.0877, Validation Loss: 6.0906
# Epoch 21, Loss: 102.5011, Validation Loss: 6.0012
# Epoch 22, Loss: 84.6837, Validation Loss: 5.8572
# Epoch 23, Loss: 68.9657, Validation Loss: 6.1675
# Epoch 24, Loss: 57.0896, Validation Loss: 6.0579
# Epoch 25, Loss: 47.3499, Validation Loss: 6.3159
# Epoch 26, Loss: 39.7620, Validation Loss: 6.1435
# Epoch 27, Loss: 33.9859, Validation Loss: 6.7330
# Epoch 28, Loss: 28.0440, Validation Loss: 6.3177
# Epoch 29, Loss: 23.4439, Validation Loss: 6.5553
# Epoch 30, Loss: 18.8303, Validation Loss: 6.7474
# Epoch 31, Loss: 15.3211, Validation Loss: 6.8325
# Epoch 32, Loss: 12.8680, Validation Loss: 6.8702
# Epoch 33, Loss: 11.1274, Validation Loss: 6.8198
# Epoch 34, Loss: 9.5977, Validation Loss: 7.2248
# Epoch 35, Loss: 8.3460, Validation Loss: 6.8024
# Epoch 36, Loss: 7.3903, Validation Loss: 7.0486
# Epoch 37, Loss: 6.4943, Validation Loss: 6.5356
# Epoch 38, Loss: 5.7323, Validation Loss: 7.1221
# Epoch 39, Loss: 5.3277, Validation Loss: 6.5292
# Epoch 40, Loss: 4.6839, Validation Loss: 6.8983
# Epoch 41, Loss: 4.5125, Validation Loss: 7.0009
# Epoch 42, Loss: 4.4743, Validation Loss: 7.0244
# Epoch 43, Loss: 4.2245, Validation Loss: 7.2056
# Epoch 44, Loss: 3.9505, Validation Loss: 7.6561
# Epoch 45, Loss: 3.4245, Validation Loss: 7.1031
# Epoch 46, Loss: 3.8395, Validation Loss: 7.3088
# Epoch 47, Loss: 4.8846, Validation Loss: 7.0433
# Epoch 48, Loss: 6.3612, Validation Loss: 7.1655
# Epoch 49, Loss: 7.5982, Validation Loss: 7.1399
# Epoch 50, Loss: 8.7744, Validation Loss: 7.4697
# Epoch 51, Loss: 8.1971, Validation Loss: 6.5853
# Epoch 52, Loss: 6.0116, Validation Loss: 6.8925
# Epoch 53, Loss: 4.3266, Validation Loss: 6.8410
# Epoch 54, Loss: 3.7736, Validation Loss: 6.9035
# Epoch 55, Loss: 3.6038, Validation Loss: 7.5796
# Epoch 56, Loss: 2.7931, Validation Loss: 7.5193
# Epoch 57, Loss: 1.9806, Validation Loss: 6.8325
# Epoch 58, Loss: 1.2908, Validation Loss: 7.2247
# Epoch 59, Loss: 1.1091, Validation Loss: 7.4524
# Epoch 60, Loss: 1.1232, Validation Loss: 7.7066
# Epoch 61, Loss: 0.9671, Validation Loss: 7.0878
# Epoch 62, Loss: 1.0359, Validation Loss: 7.9285
# Epoch 63, Loss: 0.8158, Validation Loss: 7.9214
# Epoch 64, Loss: 0.6629, Validation Loss: 7.2974
# Epoch 65, Loss: 0.6506, Validation Loss: 7.9881
# Epoch 66, Loss: 0.6787, Validation Loss: 7.6861
# Epoch 67, Loss: 0.5584, Validation Loss: 7.2929
# Epoch 68, Loss: 0.5972, Validation Loss: 7.8564
# Epoch 69, Loss: 0.5369, Validation Loss: 8.1201
# Epoch 70, Loss: 0.5343, Validation Loss: 6.8475
# Epoch 71, Loss: 0.6131, Validation Loss: 7.3711
# Epoch 72, Loss: 0.5933, Validation Loss: 7.4609
# Epoch 73, Loss: 0.6565, Validation Loss: 8.7625
# Epoch 74, Loss: 0.6152, Validation Loss: 7.2870
# Epoch 75, Loss: 1.3279, Validation Loss: 8.3005
# Epoch 76, Loss: 30.0223, Validation Loss: 7.5144
# Epoch 77, Loss: 54.1773, Validation Loss: 7.1770
# Epoch 78, Loss: 22.9981, Validation Loss: 7.1678
# Epoch 79, Loss: 6.9822, Validation Loss: 7.6579
# Epoch 80, Loss: 2.7892, Validation Loss: 7.7492
# Epoch 81, Loss: 1.2305, Validation Loss: 7.8721
# Epoch 82, Loss: 0.9273, Validation Loss: 7.2580
# Epoch 83, Loss: 0.7188, Validation Loss: 7.8680
# Epoch 84, Loss: 0.6582, Validation Loss: 7.4092
# Epoch 85, Loss: 0.5895, Validation Loss: 7.4797
# Epoch 86, Loss: 0.5850, Validation Loss: 7.7777
# Epoch 87, Loss: 0.5740, Validation Loss: 7.6166
# Epoch 88, Loss: 0.4736, Validation Loss: 7.7818
# Epoch 89, Loss: 0.5282, Validation Loss: 7.4050
# Epoch 90, Loss: 0.4792, Validation Loss: 7.6396
# Epoch 91, Loss: 0.4418, Validation Loss: 7.8451
# Epoch 92, Loss: 0.4512, Validation Loss: 8.2539
# Epoch 93, Loss: 0.4519, Validation Loss: 7.1233
# Epoch 94, Loss: 0.4290, Validation Loss: 7.8953
# Epoch 95, Loss: 0.3860, Validation Loss: 7.7991
# Epoch 96, Loss: 0.3585, Validation Loss: 7.9920
# Epoch 97, Loss: 0.3927, Validation Loss: 8.7686
# Epoch 98, Loss: 0.3508, Validation Loss: 7.8086
# Epoch 99, Loss: 0.3701, Validation Loss: 8.7812
# Epoch 100, Loss: 0.3722, Validation Loss: 7.2400
# Epoch 101, Loss: 0.3344, Validation Loss: 7.8051
# Epoch 102, Loss: 0.3288, Validation Loss: 7.6369
# Epoch 103, Loss: 0.2949, Validation Loss: 8.2184
# Epoch 104, Loss: 0.3085, Validation Loss: 7.1683
# Epoch 105, Loss: 0.2614, Validation Loss: 7.4038
# Epoch 106, Loss: 0.3456, Validation Loss: 7.0706
# Epoch 107, Loss: 0.3395, Validation Loss: 7.5716
# Epoch 108, Loss: 0.3866, Validation Loss: 7.6378
# Epoch 109, Loss: 0.2989, Validation Loss: 7.3267
# Epoch 110, Loss: 0.3048, Validation Loss: 8.2374
# Epoch 111, Loss: 0.3635, Validation Loss: 7.8426
# Epoch 112, Loss: 0.3054, Validation Loss: 8.3041
# Epoch 113, Loss: 0.3089, Validation Loss: 7.7740
# Epoch 114, Loss: 0.3431, Validation Loss: 7.9301
# Epoch 115, Loss: 0.2589, Validation Loss: 7.7579
# Epoch 116, Loss: 0.2628, Validation Loss: 7.7322
# Epoch 117, Loss: 0.2040, Validation Loss: 7.8936
# Epoch 118, Loss: 0.2203, Validation Loss: 8.0711
# Epoch 119, Loss: 0.2871, Validation Loss: 8.9954
# Epoch 120, Loss: 0.2858, Validation Loss: 7.9272
# Epoch 121, Loss: 0.2320, Validation Loss: 8.3195
# Epoch 122, Loss: 0.3196, Validation Loss: 8.7872
# Epoch 123, Loss: 0.3198, Validation Loss: 9.1412
# Epoch 124, Loss: 0.2560, Validation Loss: 7.6625
# Epoch 125, Loss: 0.2201, Validation Loss: 8.2597
# Epoch 126, Loss: 0.5748, Validation Loss: 7.9637
# Epoch 127, Loss: 61.7910, Validation Loss: 7.4729
# Epoch 128, Loss: 39.9871, Validation Loss: 7.0683
# Epoch 129, Loss: 11.4276, Validation Loss: 7.9504
# Epoch 130, Loss: 3.0900, Validation Loss: 8.1018
# Epoch 131, Loss: 1.2274, Validation Loss: 7.3032
# Epoch 132, Loss: 0.7689, Validation Loss: 7.9308
# Epoch 133, Loss: 0.6066, Validation Loss: 8.5661
# Epoch 134, Loss: 0.5857, Validation Loss: 8.1630
# Epoch 135, Loss: 0.4705, Validation Loss: 7.7020
# Epoch 136, Loss: 0.3920, Validation Loss: 8.2140
# Epoch 137, Loss: 0.4183, Validation Loss: 8.0114
# Epoch 138, Loss: 0.4129, Validation Loss: 7.3421
# Epoch 139, Loss: 0.3975, Validation Loss: 8.2327
# Epoch 140, Loss: 0.3956, Validation Loss: 8.1406
# Epoch 141, Loss: 0.3921, Validation Loss: 7.9812
# Epoch 142, Loss: 0.4200, Validation Loss: 7.6296
# Epoch 143, Loss: 0.3431, Validation Loss: 8.1472
# Epoch 144, Loss: 0.3587, Validation Loss: 7.5688
# Epoch 145, Loss: 0.3371, Validation Loss: 8.3527
# Epoch 146, Loss: 0.3059, Validation Loss: 8.3542
# Epoch 147, Loss: 0.3318, Validation Loss: 7.7129
# Epoch 148, Loss: 0.3147, Validation Loss: 8.0960
# Epoch 149, Loss: 0.2752, Validation Loss: 8.0825
# Epoch 150, Loss: 0.2458, Validation Loss: 8.0041
# Epoch 151, Loss: 0.2259, Validation Loss: 7.5733
# Epoch 152, Loss: 0.2675, Validation Loss: 8.2565
# Epoch 153, Loss: 0.2507, Validation Loss: 8.8025
# Epoch 154, Loss: 0.2787, Validation Loss: 8.1985
# Epoch 155, Loss: 0.2319, Validation Loss: 7.7740
# Epoch 156, Loss: 0.2784, Validation Loss: 8.7099
# Epoch 157, Loss: 0.1892, Validation Loss: 7.9854
# Epoch 158, Loss: 0.2241, Validation Loss: 8.1762
# Epoch 159, Loss: 0.2137, Validation Loss: 9.0420
# Epoch 160, Loss: 0.2277, Validation Loss: 8.6538
# Epoch 161, Loss: 0.2292, Validation Loss: 8.9207
# Epoch 162, Loss: 0.2777, Validation Loss: 9.0286
# Epoch 163, Loss: 0.2725, Validation Loss: 8.4322
# Epoch 164, Loss: 0.2785, Validation Loss: 8.9212
# Epoch 165, Loss: 0.2148, Validation Loss: 9.6882
# Epoch 166, Loss: 0.2374, Validation Loss: 8.2895
# Epoch 167, Loss: 0.2230, Validation Loss: 8.0501
# Epoch 168, Loss: 0.2643, Validation Loss: 8.9482
# Epoch 169, Loss: 0.1803, Validation Loss: 8.2581
# Epoch 170, Loss: 0.2009, Validation Loss: 9.2568
# Epoch 171, Loss: 0.2190, Validation Loss: 8.9312
# Epoch 172, Loss: 0.2742, Validation Loss: 8.6649
# Epoch 173, Loss: 0.2744, Validation Loss: 8.2914
# Epoch 174, Loss: 6.7622, Validation Loss: 8.5851
# Epoch 175, Loss: 57.4910, Validation Loss: 7.7774
# Epoch 176, Loss: 25.2366, Validation Loss: 8.3590
# Epoch 177, Loss: 5.6271, Validation Loss: 7.6530
# Epoch 178, Loss: 1.4732, Validation Loss: 7.6435
# Epoch 179, Loss: 0.9343, Validation Loss: 7.4751
# Epoch 180, Loss: 0.6808, Validation Loss: 8.5168
# Epoch 181, Loss: 0.5839, Validation Loss: 7.8740
# Epoch 182, Loss: 0.5304, Validation Loss: 8.0164
# Epoch 183, Loss: 0.3926, Validation Loss: 8.7446
# Epoch 184, Loss: 0.3405, Validation Loss: 7.9272
# Epoch 185, Loss: 0.3793, Validation Loss: 8.1960
# Epoch 186, Loss: 0.3233, Validation Loss: 8.3490
# Epoch 187, Loss: 0.3830, Validation Loss: 7.9107
# Epoch 188, Loss: 0.3184, Validation Loss: 7.9134
# Epoch 189, Loss: 0.3165, Validation Loss: 8.5005
# Epoch 190, Loss: 0.2968, Validation Loss: 8.5146
# Epoch 191, Loss: 0.3132, Validation Loss: 8.1908
# Epoch 192, Loss: 0.2698, Validation Loss: 9.5821
# Epoch 193, Loss: 0.2677, Validation Loss: 7.8088
# Epoch 194, Loss: 0.2970, Validation Loss: 8.2739
# Epoch 195, Loss: 0.2461, Validation Loss: 7.8586
# Epoch 196, Loss: 0.2711, Validation Loss: 8.9208
# Epoch 197, Loss: 0.2530, Validation Loss: 8.0082
# Epoch 198, Loss: 0.2548, Validation Loss: 8.1247
# Epoch 199, Loss: 0.2628, Validation Loss: 8.7368
# Epoch 200, Loss: 0.2263, Validation Loss: 8.8523
# Translate: soy estudiante.
# BLEU Score: 0.08154921295365056
# No Attention Visualization (without_attention Mode).
#
# Running Mode: BAHDANAU
# Epoch 1, Loss: 796.6582, Validation Loss: 5.8348
# Epoch 2, Loss: 639.3773, Validation Loss: 5.5254
# Epoch 3, Loss: 516.9352, Validation Loss: 5.3541
# Epoch 4, Loss: 401.8937, Validation Loss: 5.3011
# Epoch 5, Loss: 303.4499, Validation Loss: 5.2750
# Epoch 6, Loss: 233.7202, Validation Loss: 5.2366
# Epoch 7, Loss: 190.8563, Validation Loss: 5.2197
# Epoch 8, Loss: 161.4561, Validation Loss: 5.2424
# Epoch 9, Loss: 133.7117, Validation Loss: 5.4038
# Epoch 10, Loss: 109.3095, Validation Loss: 5.2740
# Epoch 11, Loss: 84.9697, Validation Loss: 5.2827
# Epoch 12, Loss: 69.1229, Validation Loss: 5.4500
# Epoch 13, Loss: 56.8399, Validation Loss: 5.3848
# Epoch 14, Loss: 47.2041, Validation Loss: 5.8366
# Epoch 15, Loss: 37.7193, Validation Loss: 5.4104
# Epoch 16, Loss: 30.1123, Validation Loss: 5.4329
# Epoch 17, Loss: 23.8950, Validation Loss: 5.6265
# Epoch 18, Loss: 19.9146, Validation Loss: 5.5475
# Epoch 19, Loss: 16.4231, Validation Loss: 5.7495
# Epoch 20, Loss: 13.7857, Validation Loss: 6.1812
# Epoch 21, Loss: 12.0396, Validation Loss: 5.5555
# Epoch 22, Loss: 10.2993, Validation Loss: 6.2143
# Epoch 23, Loss: 8.8512, Validation Loss: 5.6399
# Epoch 24, Loss: 8.0247, Validation Loss: 5.9819
# Epoch 25, Loss: 6.4996, Validation Loss: 6.0312
# Epoch 26, Loss: 6.0339, Validation Loss: 5.9334
# Epoch 27, Loss: 5.6360, Validation Loss: 5.5129
# Epoch 28, Loss: 5.5127, Validation Loss: 6.1476
# Epoch 29, Loss: 5.4336, Validation Loss: 6.4030
# Epoch 30, Loss: 6.3619, Validation Loss: 5.9310
# Epoch 31, Loss: 6.5788, Validation Loss: 6.6616
# Epoch 32, Loss: 7.6491, Validation Loss: 5.8368
# Epoch 33, Loss: 10.1886, Validation Loss: 6.5737
# Epoch 34, Loss: 14.8103, Validation Loss: 6.2556
# Epoch 35, Loss: 20.8046, Validation Loss: 6.3682
# Epoch 36, Loss: 23.6163, Validation Loss: 5.9887
# Epoch 37, Loss: 21.4805, Validation Loss: 5.9235
# Epoch 38, Loss: 14.8354, Validation Loss: 6.3201
# Epoch 39, Loss: 9.3328, Validation Loss: 5.8190
# Epoch 40, Loss: 6.1535, Validation Loss: 6.7414
# Epoch 41, Loss: 4.2366, Validation Loss: 6.0078
# Epoch 42, Loss: 3.4479, Validation Loss: 5.8922
# Epoch 43, Loss: 2.7601, Validation Loss: 5.9874
# Epoch 44, Loss: 2.2417, Validation Loss: 6.4715
# Epoch 45, Loss: 2.2157, Validation Loss: 6.1800
# Epoch 46, Loss: 1.9867, Validation Loss: 6.1498
# Epoch 47, Loss: 2.1386, Validation Loss: 5.9346
# Epoch 48, Loss: 1.9578, Validation Loss: 6.9271
# Epoch 49, Loss: 1.7959, Validation Loss: 6.4495
# Epoch 50, Loss: 1.6466, Validation Loss: 6.3839
# Epoch 51, Loss: 1.6525, Validation Loss: 6.4587
# Epoch 52, Loss: 1.7476, Validation Loss: 6.4994
# Epoch 53, Loss: 1.8641, Validation Loss: 6.7494
# Epoch 54, Loss: 2.1018, Validation Loss: 5.9220
# Epoch 55, Loss: 2.4823, Validation Loss: 5.9079
# Epoch 56, Loss: 6.7557, Validation Loss: 6.2424
# Epoch 57, Loss: 20.3529, Validation Loss: 6.3287
# Epoch 58, Loss: 34.3358, Validation Loss: 6.2265
# Epoch 59, Loss: 29.3261, Validation Loss: 5.6756
# Epoch 60, Loss: 17.7561, Validation Loss: 5.8230
# Epoch 61, Loss: 9.1228, Validation Loss: 6.7214
# Epoch 62, Loss: 4.5972, Validation Loss: 6.7075
# Epoch 63, Loss: 2.5534, Validation Loss: 6.1261
# Epoch 64, Loss: 1.8290, Validation Loss: 6.2746
# Epoch 65, Loss: 1.6838, Validation Loss: 6.7788
# Epoch 66, Loss: 1.2507, Validation Loss: 6.2219
# Epoch 67, Loss: 1.2014, Validation Loss: 6.1201
# Epoch 68, Loss: 1.1053, Validation Loss: 6.9766
# Epoch 69, Loss: 1.3512, Validation Loss: 6.5793
# Epoch 70, Loss: 1.1343, Validation Loss: 6.8394
# Epoch 71, Loss: 1.0299, Validation Loss: 6.2199
# Epoch 72, Loss: 1.1064, Validation Loss: 6.2150
# Epoch 73, Loss: 0.9395, Validation Loss: 7.6140
# Epoch 74, Loss: 1.0600, Validation Loss: 6.3810
# Epoch 75, Loss: 1.0366, Validation Loss: 6.7395
# Epoch 76, Loss: 0.9811, Validation Loss: 6.3339
# Epoch 77, Loss: 0.9626, Validation Loss: 6.8255
# Epoch 78, Loss: 1.0775, Validation Loss: 6.6732
# Epoch 79, Loss: 1.3376, Validation Loss: 7.3831
# Epoch 80, Loss: 1.3259, Validation Loss: 6.6828
# Epoch 81, Loss: 1.4178, Validation Loss: 6.5002
# Epoch 82, Loss: 2.1716, Validation Loss: 6.8223
# Epoch 83, Loss: 4.9589, Validation Loss: 6.1535
# Epoch 84, Loss: 17.4406, Validation Loss: 6.1666
# Epoch 85, Loss: 29.0473, Validation Loss: 6.1318
# Epoch 86, Loss: 22.6859, Validation Loss: 6.6100
# Epoch 87, Loss: 11.3766, Validation Loss: 6.6500
# Epoch 88, Loss: 5.6048, Validation Loss: 5.9974
# Epoch 89, Loss: 2.4413, Validation Loss: 6.4013
# Epoch 90, Loss: 1.4085, Validation Loss: 6.0795
# Epoch 91, Loss: 1.0370, Validation Loss: 6.1991
# Epoch 92, Loss: 1.0255, Validation Loss: 6.0232
# Epoch 93, Loss: 0.8717, Validation Loss: 6.8794
# Epoch 94, Loss: 0.7533, Validation Loss: 7.1015
# Epoch 95, Loss: 0.7788, Validation Loss: 7.3054
# Epoch 96, Loss: 0.7784, Validation Loss: 6.8731
# Epoch 97, Loss: 0.7643, Validation Loss: 6.7830
# Epoch 98, Loss: 0.6658, Validation Loss: 7.1719
# Epoch 99, Loss: 0.8126, Validation Loss: 6.6801
# Epoch 100, Loss: 0.6776, Validation Loss: 6.9194
# Epoch 101, Loss: 0.7560, Validation Loss: 6.9007
# Epoch 102, Loss: 0.8034, Validation Loss: 7.1093
# Epoch 103, Loss: 0.8385, Validation Loss: 6.9149
# Epoch 104, Loss: 0.8082, Validation Loss: 6.7185
# Epoch 105, Loss: 0.7256, Validation Loss: 7.0429
# Epoch 106, Loss: 0.8058, Validation Loss: 7.2733
# Epoch 107, Loss: 0.6355, Validation Loss: 6.7308
# Epoch 108, Loss: 0.7236, Validation Loss: 6.6777
# Epoch 109, Loss: 0.7744, Validation Loss: 6.2227
# Epoch 110, Loss: 0.8039, Validation Loss: 7.5201
# Epoch 111, Loss: 1.0691, Validation Loss: 6.8597
# Epoch 112, Loss: 1.0356, Validation Loss: 7.0451
# Epoch 113, Loss: 1.1900, Validation Loss: 7.6133
# Epoch 114, Loss: 2.9211, Validation Loss: 6.3340
# Epoch 115, Loss: 15.8487, Validation Loss: 6.9038
# Epoch 116, Loss: 30.5882, Validation Loss: 6.6887
# Epoch 117, Loss: 20.7797, Validation Loss: 6.5409
# Epoch 118, Loss: 9.6697, Validation Loss: 6.9548
# Epoch 119, Loss: 3.7930, Validation Loss: 6.1691
# Epoch 120, Loss: 2.2675, Validation Loss: 7.6882
# Epoch 121, Loss: 1.4363, Validation Loss: 6.8767
# Epoch 122, Loss: 0.8854, Validation Loss: 6.6628
# Epoch 123, Loss: 0.6631, Validation Loss: 6.8056
# Epoch 124, Loss: 0.5845, Validation Loss: 6.6089
# Epoch 125, Loss: 0.6940, Validation Loss: 6.3901
# Epoch 126, Loss: 0.6642, Validation Loss: 7.1020
# Epoch 127, Loss: 0.6070, Validation Loss: 6.7677
# Epoch 128, Loss: 0.6802, Validation Loss: 6.4174
# Epoch 129, Loss: 0.6102, Validation Loss: 6.5097
# Epoch 130, Loss: 0.5951, Validation Loss: 6.7310
# Epoch 131, Loss: 0.6209, Validation Loss: 7.3870
# Epoch 132, Loss: 0.4908, Validation Loss: 6.5710
# Epoch 133, Loss: 0.5216, Validation Loss: 7.6288
# Epoch 134, Loss: 0.5686, Validation Loss: 6.4314
# Epoch 135, Loss: 0.4629, Validation Loss: 6.7572
# Epoch 136, Loss: 0.5797, Validation Loss: 7.1381
# Epoch 137, Loss: 0.6542, Validation Loss: 6.8423
# Epoch 138, Loss: 0.6485, Validation Loss: 7.1885
# Epoch 139, Loss: 0.7422, Validation Loss: 6.8557
# Epoch 140, Loss: 0.7299, Validation Loss: 7.0315
# Epoch 141, Loss: 1.0065, Validation Loss: 6.5391
# Epoch 142, Loss: 1.2491, Validation Loss: 6.9400
# Epoch 143, Loss: 2.6089, Validation Loss: 6.8039
# Epoch 144, Loss: 6.7959, Validation Loss: 7.1057
# Epoch 145, Loss: 11.9495, Validation Loss: 6.5677
# Epoch 146, Loss: 12.5884, Validation Loss: 6.8501
# Epoch 147, Loss: 11.1687, Validation Loss: 6.5116
# Epoch 148, Loss: 6.0009, Validation Loss: 6.9507
# Epoch 149, Loss: 2.8361, Validation Loss: 6.6178
# Epoch 150, Loss: 1.6434, Validation Loss: 6.3764
# Epoch 151, Loss: 0.7850, Validation Loss: 7.6084
# Epoch 152, Loss: 0.7118, Validation Loss: 7.0125
# Epoch 153, Loss: 0.5812, Validation Loss: 6.7489
# Epoch 154, Loss: 0.5507, Validation Loss: 6.4489
# Epoch 155, Loss: 0.5174, Validation Loss: 6.9820
# Epoch 156, Loss: 0.5199, Validation Loss: 6.6423
# Epoch 157, Loss: 0.5112, Validation Loss: 6.4239
# Epoch 158, Loss: 0.5112, Validation Loss: 6.4649
# Epoch 159, Loss: 0.5373, Validation Loss: 7.2977
# Epoch 160, Loss: 0.5578, Validation Loss: 6.9089
# Epoch 161, Loss: 0.5782, Validation Loss: 7.2714
# Epoch 162, Loss: 0.5090, Validation Loss: 6.6234
# Epoch 163, Loss: 0.4625, Validation Loss: 6.8822
# Epoch 164, Loss: 0.4641, Validation Loss: 7.2580
# Epoch 165, Loss: 0.4438, Validation Loss: 7.0041
# Epoch 166, Loss: 0.4784, Validation Loss: 7.1800
# Epoch 167, Loss: 0.4942, Validation Loss: 7.2109
# Epoch 168, Loss: 0.5552, Validation Loss: 7.7434
# Epoch 169, Loss: 0.4768, Validation Loss: 8.0349
# Epoch 170, Loss: 0.4786, Validation Loss: 7.0294
# Epoch 171, Loss: 0.3669, Validation Loss: 7.2739
# Epoch 172, Loss: 0.5764, Validation Loss: 7.4140
# Epoch 173, Loss: 0.5067, Validation Loss: 6.8766
# Epoch 174, Loss: 0.5579, Validation Loss: 6.7518
# Epoch 175, Loss: 0.8047, Validation Loss: 6.4411
# Epoch 176, Loss: 0.8998, Validation Loss: 6.3176
# Epoch 177, Loss: 2.0651, Validation Loss: 7.1986
# Epoch 178, Loss: 8.3883, Validation Loss: 6.8555
# Epoch 179, Loss: 17.8600, Validation Loss: 6.9919
# Epoch 180, Loss: 15.4440, Validation Loss: 7.4964
# Epoch 181, Loss: 7.6375, Validation Loss: 6.5356
# Epoch 182, Loss: 3.1969, Validation Loss: 7.1672
# Epoch 183, Loss: 1.1412, Validation Loss: 7.1992
# Epoch 184, Loss: 0.7940, Validation Loss: 7.1657
# Epoch 185, Loss: 0.4878, Validation Loss: 6.6756
# Epoch 186, Loss: 0.4121, Validation Loss: 7.2940
# Epoch 187, Loss: 0.4646, Validation Loss: 7.2837
# Epoch 188, Loss: 0.3770, Validation Loss: 6.8708
# Epoch 189, Loss: 0.4161, Validation Loss: 7.5838
# Epoch 190, Loss: 0.4321, Validation Loss: 7.2651
# Epoch 191, Loss: 0.3970, Validation Loss: 7.6259
# Epoch 192, Loss: 0.3976, Validation Loss: 7.6082
# Epoch 193, Loss: 0.4217, Validation Loss: 6.6606
# Epoch 194, Loss: 0.3443, Validation Loss: 6.7505
# Epoch 195, Loss: 0.4404, Validation Loss: 7.4435
# Epoch 196, Loss: 0.3323, Validation Loss: 7.0664
# Epoch 197, Loss: 0.3377, Validation Loss: 7.3940
# Epoch 198, Loss: 0.3845, Validation Loss: 7.1355
# Epoch 199, Loss: 0.3662, Validation Loss: 7.3686
# Epoch 200, Loss: 0.3317, Validation Loss: 6.5292
# Translate: estoy feliz.
# BLEU Score: 0.10986906985257856
# Running Mode: LUONG
# Epoch 1, Loss: 804.9626, Validation Loss: 6.0032
# Epoch 2, Loss: 664.7034, Validation Loss: 5.5218
# Epoch 3, Loss: 563.5253, Validation Loss: 5.5176
# Epoch 4, Loss: 459.8352, Validation Loss: 5.2980
# Epoch 5, Loss: 369.5484, Validation Loss: 5.3353
# Epoch 6, Loss: 297.0011, Validation Loss: 5.2613
# Epoch 7, Loss: 242.6972, Validation Loss: 5.2878
# Epoch 8, Loss: 204.9449, Validation Loss: 5.2723
# Epoch 9, Loss: 175.3073, Validation Loss: 5.4052
# Epoch 10, Loss: 150.4288, Validation Loss: 5.0943
# Epoch 11, Loss: 128.1825, Validation Loss: 5.4034
# Epoch 12, Loss: 107.7584, Validation Loss: 5.2477
# Epoch 13, Loss: 90.0717, Validation Loss: 5.2391
# Epoch 14, Loss: 72.3524, Validation Loss: 5.2797
# Epoch 15, Loss: 58.8182, Validation Loss: 5.3434
# Epoch 16, Loss: 54.0704, Validation Loss: 5.3613
# Epoch 17, Loss: 44.7741, Validation Loss: 5.6631
# Epoch 18, Loss: 35.8326, Validation Loss: 5.3007
# Epoch 19, Loss: 31.6131, Validation Loss: 5.5114
# Epoch 20, Loss: 31.8748, Validation Loss: 5.3185
# Epoch 21, Loss: 25.6588, Validation Loss: 5.7027
# Epoch 22, Loss: 19.8080, Validation Loss: 6.1071
# Epoch 23, Loss: 19.9367, Validation Loss: 5.7126
# Epoch 24, Loss: 17.7380, Validation Loss: 5.6522
# Epoch 25, Loss: 16.7064, Validation Loss: 5.8773
# Epoch 26, Loss: 14.7115, Validation Loss: 6.6343
# Epoch 27, Loss: 13.3284, Validation Loss: 6.2301
# Epoch 28, Loss: 13.0977, Validation Loss: 5.8853
# Epoch 29, Loss: 11.6507, Validation Loss: 5.9070
# Epoch 30, Loss: 8.5805, Validation Loss: 6.3230
# Epoch 31, Loss: 6.8572, Validation Loss: 5.9823
# Epoch 32, Loss: 6.5463, Validation Loss: 5.9609
# Epoch 33, Loss: 10.5987, Validation Loss: 6.1266
# Epoch 34, Loss: 12.1130, Validation Loss: 6.2262
# Epoch 35, Loss: 13.1167, Validation Loss: 5.8064
# Epoch 36, Loss: 14.3717, Validation Loss: 6.3951
# Epoch 37, Loss: 15.1572, Validation Loss: 6.1295
# Epoch 38, Loss: 15.2715, Validation Loss: 6.4616
# Epoch 39, Loss: 16.7418, Validation Loss: 5.9860
# Epoch 40, Loss: 14.4647, Validation Loss: 6.4010
# Epoch 41, Loss: 12.7817, Validation Loss: 6.2239
# Epoch 42, Loss: 9.1985, Validation Loss: 5.9783
# Epoch 43, Loss: 7.0998, Validation Loss: 6.3809
# Epoch 44, Loss: 5.6415, Validation Loss: 6.1626
# Epoch 45, Loss: 4.4575, Validation Loss: 6.2715
# Epoch 46, Loss: 3.6705, Validation Loss: 6.3867
# Epoch 47, Loss: 3.8096, Validation Loss: 6.5094
# Epoch 48, Loss: 4.1593, Validation Loss: 6.3336
# Epoch 49, Loss: 3.4041, Validation Loss: 6.3821
# Epoch 50, Loss: 3.6822, Validation Loss: 6.3360
# Epoch 51, Loss: 8.5903, Validation Loss: 6.1343
# Epoch 52, Loss: 9.9475, Validation Loss: 6.8573
# Epoch 53, Loss: 14.9608, Validation Loss: 6.3201
# Epoch 54, Loss: 13.3598, Validation Loss: 7.0374
# Epoch 55, Loss: 15.0015, Validation Loss: 6.5082
# Epoch 56, Loss: 20.3671, Validation Loss: 6.2774
# Epoch 57, Loss: 15.3297, Validation Loss: 6.2708
# Epoch 58, Loss: 13.9576, Validation Loss: 6.9026
# Epoch 59, Loss: 8.6422, Validation Loss: 6.8662
# Epoch 60, Loss: 5.7474, Validation Loss: 6.1769
# Epoch 61, Loss: 3.7083, Validation Loss: 6.9658
# Epoch 62, Loss: 2.8643, Validation Loss: 6.4424
# Epoch 63, Loss: 2.2796, Validation Loss: 6.5804
# Epoch 64, Loss: 2.3921, Validation Loss: 6.8111
# Epoch 65, Loss: 2.1596, Validation Loss: 6.2298
# Epoch 66, Loss: 1.8639, Validation Loss: 6.6445
# Epoch 67, Loss: 1.9391, Validation Loss: 6.3252
# Epoch 68, Loss: 1.7462, Validation Loss: 6.2231
# Epoch 69, Loss: 1.8614, Validation Loss: 7.4138
# Epoch 70, Loss: 1.7874, Validation Loss: 6.9313
# Epoch 71, Loss: 1.4915, Validation Loss: 6.3611
# Epoch 72, Loss: 1.6136, Validation Loss: 6.5228
# Epoch 73, Loss: 1.7582, Validation Loss: 7.0877
# Epoch 74, Loss: 1.5477, Validation Loss: 6.8631
# Epoch 75, Loss: 1.6036, Validation Loss: 6.3764
# Epoch 76, Loss: 1.9447, Validation Loss: 6.6094
# Epoch 77, Loss: 4.0580, Validation Loss: 6.7366
# Epoch 78, Loss: 11.0906, Validation Loss: 6.1784
# Epoch 79, Loss: 29.1445, Validation Loss: 6.9358
# Epoch 80, Loss: 43.9922, Validation Loss: 6.6931
# Epoch 81, Loss: 30.4296, Validation Loss: 6.4061
# Epoch 82, Loss: 14.4585, Validation Loss: 6.5391
# Epoch 83, Loss: 6.5201, Validation Loss: 6.4629
# Epoch 84, Loss: 3.6782, Validation Loss: 6.1535
# Epoch 85, Loss: 3.1982, Validation Loss: 6.6465
# Epoch 86, Loss: 2.5872, Validation Loss: 6.4392
# Epoch 87, Loss: 2.9019, Validation Loss: 6.5375
# Epoch 88, Loss: 2.1318, Validation Loss: 6.8249
# Epoch 89, Loss: 1.8205, Validation Loss: 6.5764
# Epoch 90, Loss: 1.6799, Validation Loss: 6.3306
# Epoch 91, Loss: 1.7001, Validation Loss: 6.6667
# Epoch 92, Loss: 1.3996, Validation Loss: 6.9811
# Epoch 93, Loss: 1.5442, Validation Loss: 6.7601
# Epoch 94, Loss: 1.4144, Validation Loss: 6.4323
# Epoch 95, Loss: 1.4062, Validation Loss: 6.7008
# Epoch 96, Loss: 1.4704, Validation Loss: 6.8746
# Epoch 97, Loss: 1.4612, Validation Loss: 7.0955
# Epoch 98, Loss: 1.5989, Validation Loss: 6.4461
# Epoch 99, Loss: 1.4089, Validation Loss: 7.0095
# Epoch 100, Loss: 1.6321, Validation Loss: 6.2168
# Epoch 101, Loss: 2.7842, Validation Loss: 6.5542
# Epoch 102, Loss: 5.5575, Validation Loss: 6.3496
# Epoch 103, Loss: 10.8398, Validation Loss: 6.6832
# Epoch 104, Loss: 13.6766, Validation Loss: 7.4346
# Epoch 105, Loss: 10.7022, Validation Loss: 7.1059
# Epoch 106, Loss: 7.6531, Validation Loss: 6.7466
# Epoch 107, Loss: 6.8355, Validation Loss: 6.7665
# Epoch 108, Loss: 7.2705, Validation Loss: 7.1565
# Epoch 109, Loss: 4.9589, Validation Loss: 6.9229
# Epoch 110, Loss: 3.1509, Validation Loss: 6.5762
# Epoch 111, Loss: 2.2384, Validation Loss: 6.5257
# Epoch 112, Loss: 2.0578, Validation Loss: 7.0375
# Epoch 113, Loss: 2.2730, Validation Loss: 7.5585
# Epoch 114, Loss: 2.0236, Validation Loss: 7.7061
# Epoch 115, Loss: 1.4482, Validation Loss: 6.9659
# Epoch 116, Loss: 1.4334, Validation Loss: 6.6571
# Epoch 117, Loss: 1.2739, Validation Loss: 7.5024
# Epoch 118, Loss: 1.2591, Validation Loss: 6.8385
# Epoch 119, Loss: 1.1372, Validation Loss: 7.1063
# Epoch 120, Loss: 1.2337, Validation Loss: 6.8079
# Epoch 121, Loss: 1.2887, Validation Loss: 7.2292
# Epoch 122, Loss: 1.1372, Validation Loss: 7.1327
# Epoch 123, Loss: 1.3494, Validation Loss: 6.9092
# Epoch 124, Loss: 1.5139, Validation Loss: 6.7395
# Epoch 125, Loss: 1.5311, Validation Loss: 7.1052
# Epoch 126, Loss: 1.1123, Validation Loss: 6.7370
# Epoch 127, Loss: 1.1554, Validation Loss: 7.3472
# Epoch 128, Loss: 1.2632, Validation Loss: 7.2564
# Epoch 129, Loss: 1.8876, Validation Loss: 6.7597
# Epoch 130, Loss: 4.9420, Validation Loss: 7.1972
# Epoch 131, Loss: 18.1646, Validation Loss: 6.7535
# Epoch 132, Loss: 41.4835, Validation Loss: 6.7584
# Epoch 133, Loss: 27.7212, Validation Loss: 6.4381
# Epoch 134, Loss: 13.0035, Validation Loss: 6.6377
# Epoch 135, Loss: 5.2562, Validation Loss: 6.7631
# Epoch 136, Loss: 2.6301, Validation Loss: 6.8060
# Epoch 137, Loss: 1.7368, Validation Loss: 6.6136
# Epoch 138, Loss: 1.5355, Validation Loss: 7.0337
# Epoch 139, Loss: 1.4933, Validation Loss: 6.5171
# Epoch 140, Loss: 1.2776, Validation Loss: 7.0791
# Epoch 141, Loss: 1.0677, Validation Loss: 7.5192
# Epoch 142, Loss: 0.9649, Validation Loss: 6.7814
# Epoch 143, Loss: 1.2251, Validation Loss: 6.6735
# Epoch 144, Loss: 0.9898, Validation Loss: 6.7176
# Epoch 145, Loss: 1.0025, Validation Loss: 6.7568
# Epoch 146, Loss: 1.2465, Validation Loss: 6.7589
# Epoch 147, Loss: 0.9084, Validation Loss: 7.0529
# Epoch 148, Loss: 1.1132, Validation Loss: 7.1161
# Epoch 149, Loss: 1.1345, Validation Loss: 7.6516
# Epoch 150, Loss: 0.9186, Validation Loss: 6.7980
# Epoch 151, Loss: 1.0802, Validation Loss: 7.0289
# Epoch 152, Loss: 1.0155, Validation Loss: 6.9734
# Epoch 153, Loss: 1.6362, Validation Loss: 7.1669
# Epoch 154, Loss: 4.6239, Validation Loss: 6.9586
# Epoch 155, Loss: 7.2641, Validation Loss: 7.6926
# Epoch 156, Loss: 8.6995, Validation Loss: 7.2373
# Epoch 157, Loss: 9.0924, Validation Loss: 7.0079
# Epoch 158, Loss: 6.8015, Validation Loss: 7.9428
# Epoch 159, Loss: 6.3348, Validation Loss: 6.9856
# Epoch 160, Loss: 4.2142, Validation Loss: 7.0512
# Epoch 161, Loss: 3.6713, Validation Loss: 7.7935
# Epoch 162, Loss: 3.0496, Validation Loss: 7.1071
# Epoch 163, Loss: 3.8203, Validation Loss: 7.0881
# Epoch 164, Loss: 3.5516, Validation Loss: 6.8863
# Epoch 165, Loss: 3.1227, Validation Loss: 6.6935
# Epoch 166, Loss: 2.5759, Validation Loss: 6.9249
# Epoch 167, Loss: 2.1859, Validation Loss: 7.4716
# Epoch 168, Loss: 1.5325, Validation Loss: 7.3727
# Epoch 169, Loss: 1.1418, Validation Loss: 7.2868
# Epoch 170, Loss: 1.0062, Validation Loss: 6.8576
# Epoch 171, Loss: 0.9209, Validation Loss: 7.7121
# Epoch 172, Loss: 0.9723, Validation Loss: 7.3649
# Epoch 173, Loss: 0.8606, Validation Loss: 7.1865
# Epoch 174, Loss: 0.8728, Validation Loss: 7.3425
# Epoch 175, Loss: 0.9204, Validation Loss: 7.7063
# Epoch 176, Loss: 0.9174, Validation Loss: 7.3867
# Epoch 177, Loss: 0.8706, Validation Loss: 7.5306
# Epoch 178, Loss: 0.9886, Validation Loss: 8.0738
# Epoch 179, Loss: 1.4181, Validation Loss: 7.7481
# Epoch 180, Loss: 1.6575, Validation Loss: 7.4917
# Epoch 181, Loss: 6.2824, Validation Loss: 7.2791
# Epoch 182, Loss: 13.8242, Validation Loss: 7.1783
# Epoch 183, Loss: 21.6291, Validation Loss: 7.3040
# Epoch 184, Loss: 14.1643, Validation Loss: 7.0743
# Epoch 185, Loss: 7.0249, Validation Loss: 7.0601
# Epoch 186, Loss: 4.8636, Validation Loss: 6.9462
# Epoch 187, Loss: 2.5231, Validation Loss: 7.5196
# Epoch 188, Loss: 1.8465, Validation Loss: 7.5027
# Epoch 189, Loss: 1.6322, Validation Loss: 6.9434
# Epoch 190, Loss: 1.0221, Validation Loss: 7.8028
# Epoch 191, Loss: 1.0509, Validation Loss: 6.9519
# Epoch 192, Loss: 0.9689, Validation Loss: 7.6056
# Epoch 193, Loss: 0.8465, Validation Loss: 6.9817
# Epoch 194, Loss: 0.7560, Validation Loss: 7.5805
# Epoch 195, Loss: 0.8224, Validation Loss: 7.6155
# Epoch 196, Loss: 0.7946, Validation Loss: 7.1966
# Epoch 197, Loss: 0.7433, Validation Loss: 7.0798
# Epoch 198, Loss: 0.6903, Validation Loss: 7.8386
# Epoch 199, Loss: 0.7979, Validation Loss: 6.7828
# Epoch 200, Loss: 0.8507, Validation Loss: 6.8148
# Translate: perdí feliz.
# BLEU Score: 0.09149062367151874
